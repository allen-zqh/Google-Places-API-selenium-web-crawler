# %%
import pandas as pd

df = pd.read_stata("/Users/zqh/Documents/RIETI_new/RIETI_AI_Survey/firm_url_for_ai_survey.dta")
df_todo = df[df['url_yes'] == 0].copy()
df_todo.loc[:, 'address'] = df_todo['pref'] + df_todo['city'] + df_todo['rest']
df_todo.to_csv('/Users/zqh/Documents/RIETI_new/RIETI_AI_Survey/todo.csv', encoding='utf_8_sig')

# %%
df = pd.read_csv("/Users/zqh/Downloads/todo.csv")
df.to_csv('/Users/zqh/Downloads/todo.csv', encoding='utf_8_sig', index=False)

# %%
df_todo.iloc[1000]
# Out:
# hojin_id                 1010601025096.0
# url
# sec_code                             NaN
# already                              0.0
# with_patent                          1.0
# time                          2021-08-10
# name                       株式会社朋コーポレーション
# type                                 301
# pref                                 東京都
# city                                 墨田区
# rest                 錦糸１丁目２番１号アルカセントラル５階
# firm                                 1.0
# all                                  1.0
# ai                                   0.0
# ai_ratio                             0.0
# url_yes                              0.0
# address        東京都墨田区錦糸１丁目２番１号アルカセントラル５階
# Name: 1685, dtype: object

# %%
df_todo.iloc[4999]
# Out:
# hojin_id        1120101005034.0
# url
# sec_code                    NaN
# already                     0.0
# with_patent                 1.0
# time                 2015-10-05
# name                 南海亜鉛鍍金株式会社
# type                        301
# pref                        大阪府
# city                       堺市堺区
# rest                  鉄砲町４２番地の１
# firm                        1.0
# all                         1.0
# ai                          0.0
# ai_ratio                    0.0
# url_yes                     0.0
# address        大阪府堺市堺区鉄砲町４２番地の１
# Name: 7201, dtype: object

# %%
import requests
import json

API_KEY = 'AIzaSyDprd-k7423yzc1uRm1_FxRgVCknMfrAAU'
#map_client = googlemaps.Client(API_KEY)

place_id = 'EmFKYXBhbiwg44CSMTMwLTAwMTMgVG9reW8sIFN1bWlkYSBDaXR5LCBLaW5zaGksIDEtY2jFjW1l4oiSMuKIku-8kSDjgqLjg6vjgqvjgrvjg7Pjg4jjg6njg6sg77yV6ZqOIiIaIAoWChQKEgk7Dgz0KIkYYBH9CVOuQCO1ExIG77yV6ZqO'
place_url = 'https://maps.googleapis.com/maps/api/place/details/json?place_id=' + place_id + '&fields=website&key=' + API_KEY

r = requests.get(place_url)
r_json = json.loads(r.text)

# %%
r_json
# Out:
# {'html_attributions': [], 'result': {}, 'status': 'OK'}

# %%
#name = '朝日テック工業株式会社'
# %40 -> @
#geocoding = '%4035.70644%2C139.80855'

url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?\
fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry%2Cplace_id\
&input=' + name + '&inputtype=textquery\
&locationbias=circle%3A2000' + geocoding + '&key=' + API_KEY

rr = requests.get(url)
rr_json = json.loads(rr.text)

# %%
rr_json
# Out:
# {'candidates': [{'formatted_address': '日本、〒103-0027 東京都中央区日本橋２丁目３−４',
#    'geometry': {'location': {'lat': 35.6813895, 'lng': 139.7719977},
#     'viewport': {'northeast': {'lat': 35.68259982989272,
#       'lng': 139.7732623298927},
#      'southwest': {'lat': 35.67990017010728, 'lng': 139.7705626701072}}},
#    'name': '株式会社アサヒ製作所 本社',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJDzWmOwFdGGARZvW7xawD1N0',
#    'rating': 0}],
#  'status': 'OK'}

# %%
rr_json['candidates'][0].get('geometry').get('location').get('lng')
# Out:
# 139.8114691

# %%
place_id = 'ChIJZf01LSCJGGAR6mTxHEDaZFQ'
place_url = 'https://maps.googleapis.com/maps/api/place/details/json?place_id=' + place_id + '&fields=website&key=' + API_KEY

r_firm = requests.get(place_url)
r_firm_result = json.loads(r_firm.text)

# %%
r_firm_result
# Out:
# {'html_attributions': [],
#  'result': {'website': 'https://tomocorporation.co.jp/'},
#  'status': 'OK'}

# %%
import pandas as pd
data = pd.read_csv('/Users/zqh/Downloads/todo.csv')
data.to_csv('/Users/zqh/Documents/RIETI_new/RIETI_AI_Survey/todo.csv', encoding = 'utf_8_sig')

# %%
import requests
import json
from tqdm import tqdm
import pandas as pd

API_KEY = 'AIzaSyDprd-k7423yzc1uRm1_FxRgVCknMfrAAU'
df = pd.read_excel('/Users/zqh/Documents/RIETI_new/RIETI_AI_Survey/todo_test.xlsx')

for ind, row in tqdm(df.iterrows()):
    name = df.loc[ind, 'name']
    geocoding = '%40' + str(df.loc[ind, 'fY']) + '%2C' + str(df.loc[ind, 'fX'])    
    url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Cgeometry%2Cplace_id&input=' + name + '&inputtype=textquery&locationbias=circle%3A2000' + geocoding + '&key=' + API_KEY

    r1 = requests.get(url)
    r1_json = json.loads(r1.text)
    if r1_json.get('candidates'):
        place_id = r1_json['candidates'][0].get('place_id')
        google_name = r1_json['candidates'][0].get('name')
        google_address = r1_json['candidates'][0].get('formatted_address')
        google_geo_lng = r1_json['candidates'][0].get('geometry').get('location').get('lng')
        google_geo_lat = r1_json['candidates'][0].get('geometry').get('location').get('lat')
        
        place_url = 'https://maps.googleapis.com/maps/api/place/details/json?place_id=' + place_id + '&fields=website&key=' + API_KEY
        r2 = requests.get(place_url)
        r2_json = json.loads(r2.text)
        try:
            firm_web = r2_json['result']['website']
        except:
            firm_web = None
        
        df.loc[ind, 'google_name'] = google_name
        df.loc[ind, 'google_placeId'] = place_id
        df.loc[ind, 'google_address'] = google_address
        df.loc[ind, 'google_geo_lng'] = google_geo_lng
        df.loc[ind, 'google_geo_lat'] = google_geo_lat
        df.loc[ind, 'website'] = firm_web
# Out:
# 26it [00:23,  1.11it/s]

# %%
df
# Out:
#         hojin_id  url  sec_code  already  with_patent       time  \
# 0  1010000000000  NaN       NaN        0            1 2015-10-05
# 1  1010000000000  NaN       NaN        0            1 2015-10-05
# 2  1010000000000  NaN       NaN        0            1 2015-10-05
# 3  1010000000000  NaN       NaN        0            1 2015-10-05
# 4  1010000000000  NaN       NaN        0            1 2022-04-28
# 5  1010000000000  NaN       NaN        0            1 2015-10-05
# 6  1010000000000  NaN       NaN        0            1 2015-10-05
# 7  1010000000000  NaN       NaN        0            1 2015-10-19
# 8  1010000000000  NaN       NaN        0            1 2015-10-05
# 9  1010000000000  NaN       NaN        0            1 2015-10-05
#
#                 name  type pref city  ...              LocName         fX  \
# 0           株式会社ウエスト   301  東京都  文京区  ...   東京都/文京区/関口/一丁目/４３番  139.72560
# 1           大田機材株式会社   301  東京都  文京区  ...   東京都/文京区/千駄木/五丁目/５番  139.75841
# ...

# %%
df
# Out:
#          hojin_id  url  sec_code  already  with_patent       time  \
# 0   1130000000000  NaN       NaN      0.0            1 2023-04-24
# 1   1470000000000  NaN       NaN      0.0            1 2015-10-05
# 2   2130000000000  NaN       NaN      0.0            1 2022-08-24
# 3   2130000000000  NaN       NaN      0.0            1 2020-01-17
# 4   2130000000000  NaN       NaN      0.0            1 2022-11-25
# 5   3100000000000  NaN       NaN      0.0            1 2023-04-03
# 6   3120000000000  NaN       NaN      0.0            1 2022-04-27
# 7   3180000000000  NaN       NaN      0.0            1 2023-06-29
# 8   3210000000000  NaN       NaN      0.0            1 2023-05-09
# 9   4100000000000  NaN       NaN      0.0            1 2015-10-05
# 10  4130000000000  NaN       NaN      0.0            1 2015-10-05
# 11  4220000000000  NaN       NaN      0.0            1 2022-08-08
# 12  5130000000000  NaN       NaN      0.0            1 2015-10-05
# ...

# %%
import requests
from tqdm import tqdm
import pandas as pd

def geocode_address(address):
    api_key = 'AIzaSyDprd-k7423yzc1uRm1_FxRgVCknMfrAAU'
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}"
    response = requests.get(url)
    data = response.json()
    if data['status'] == 'OK':
        result = data['results'][0]
        en_address = result['formatted_address']
        lat = result['geometry']['location']['lat']
        lon = result['geometry']['location']['lng']
        place_id = result['place_id']
        types = result['types']
        return en_address, lat, lon, place_id, types
    else:
        return None, None, None, None, None
    
df = pd.read_stata('/Users/zqh/Desktop/geocoding_pct_patent.dta')
en_addresses = []
lats = []
lons = []
place_ids = []
types_list = []

for address in tqdm(df['address']):
    en_address, lat, lon, place_id, types = geocode_address(address)
    en_addresses.append(en_address)
    lats.append(lat)
    lons.append(lon)
    place_ids.append(place_id)
    types_list.append(types)

df['en_address'] = en_addresses
df['lon'] = lons
df['lat'] = lats
df['place_id'] = place_ids
df['types'] = types_list

df.to_csv('/Users/zqh/Desktop/geocoding_pct_patent.csv', index=False, encoding='utf_8_sig')
# Out:
# 100%|██████████| 2763/2763 [15:42<00:00,  2.93it/s]
